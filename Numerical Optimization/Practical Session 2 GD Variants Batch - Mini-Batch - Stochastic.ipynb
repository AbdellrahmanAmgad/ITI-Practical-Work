# %% [markdown]
# # Name: Abdellrahman Amgad
# # Group: 1

# %% [markdown]
# ## Practical Work 2

# %% [markdown]
# For this practical work, the student will have to develop a Python program that is able to implement the gradient descent variants (Batch/Mini-Batch/Stochastic) in order to achieve the linear regression of a set of datapoints.

# %% [markdown]
# #### Import numpy, matplotlib.pyplot and make it inline

# %%
import numpy as np
import random

# %% [markdown]
# To have a dataset or set of data points, the student must generate a pair of arrays <b>X</b> and <b>y</b> with the values in <b>X</b> equally distributed between <b>0</b> and <b>20</b> and the values in <b>y</b> such that:
# <b>yi = a*xi + b (and a = -2, b = 1)</b>

# %%
x=np.linspace(0,20)
y=(-2*x+1)
x
# Out:
# array([ 0.        ,  0.40816327,  0.81632653,  1.2244898 ,  1.63265306,
#         2.04081633,  2.44897959,  2.85714286,  3.26530612,  3.67346939,
#         4.08163265,  4.48979592,  4.89795918,  5.30612245,  5.71428571,
#         6.12244898,  6.53061224,  6.93877551,  7.34693878,  7.75510204,
#         8.16326531,  8.57142857,  8.97959184,  9.3877551 ,  9.79591837,
#        10.20408163, 10.6122449 , 11.02040816, 11.42857143, 11.83673469,
#        12.24489796, 12.65306122, 13.06122449, 13.46938776, 13.87755102,
#        14.28571429, 14.69387755, 15.10204082, 15.51020408, 15.91836735,
#        16.32653061, 16.73469388, 17.14285714, 17.55102041, 17.95918367,
#        18.36734694, 18.7755102 , 19.18367347, 19.59183673, 20.        ])

# %%
y
# Out:
# array([  1.        ,   0.18367347,  -0.63265306,  -1.44897959,
#         -2.26530612,  -3.08163265,  -3.89795918,  -4.71428571,
#         -5.53061224,  -6.34693878,  -7.16326531,  -7.97959184,
#         -8.79591837,  -9.6122449 , -10.42857143, -11.24489796,
#        -12.06122449, -12.87755102, -13.69387755, -14.51020408,
#        -15.32653061, -16.14285714, -16.95918367, -17.7755102 ,
#        -18.59183673, -19.40816327, -20.2244898 , -21.04081633,
#        -21.85714286, -22.67346939, -23.48979592, -24.30612245,
#        -25.12244898, -25.93877551, -26.75510204, -27.57142857,
#        -28.3877551 , -29.20408163, -30.02040816, -30.83673469,
#        -31.65306122, -32.46938776, -33.28571429, -34.10204082,
#        -34.91836735, -35.73469388, -36.55102041, -37.36734694,
#        -38.18367347, -39.        ])

# %%
def GD(x,y,alpha,iterations):
    theta0_1=0
    theta1_1=0
    costs=[]
    all_theta0=[]
    all_theta1=[]
    all_h=[]
    for i in range(iterations):
        cost=0
        hypothesis=theta0_1+theta1_1*x
        all_h.append(hypothesis)
        cost=1/2*(len(x))*((np.linalg.norm(hypothesis-y))**2)
        costs.append(cost)
        gradients=[(1/len(x))*np.sum(hypothesis-y),(1/len(x))*np.sum(x.dot(hypothesis-y))]
        theta0_1=theta0_1-alpha*gradients[0]
        all_theta0.append(theta0_1)
        theta1_1=theta1_1-alpha*gradients[1]
        all_theta1.append(theta1_1)
    return all_theta0,all_theta1,costs,all_h[-1],all_h,theta0_1,theta1_1
all_theta0,all_theta1,cost,hypothesis,all_h,theta0,theta1=GD(x,y,0.001,50)

# %%
hypothesis
cost
# Out:
# [624719.3877551021,
#  467063.6225455486,
#  349220.93790054065,
#  261137.25468456672,
#  195297.47105572378,
#  146084.28930499163,
#  109298.95947320834,
#  81803.05056867606,
#  61250.68603635668,
#  45888.398355044184,
#  34405.52676497722,
#  25822.394365152682,
#  19406.724078366962,
#  14611.162264606213,
#  11026.579624912945,
#  8347.1651240976,
#  6344.334816978372,
#  4847.229532421726,
#  3728.1375173645906,
#  2891.5983305391323,
#  2266.258352337626,
#  1798.7830395310211,
#  1449.306530830911,
#  1188.0303729229156,
#  992.6811772140279,
#  846.6102997532819,
#  737.3734128925587,
#  655.668780638898,
#  594.5436535169149,
#  548.8010741697315,
#  514.556483562182,
#  488.90629833195123,
#  469.68018298423857,
#  455.255881298892,
#  444.4208087433332,
#  436.26859723827306,
#  430.1217656866244,
#  425.4739186728868,
#  421.94654184392374,
#  419.25670784112344,
#  417.19293751998873,
#  415.5971569855969,
#  414.3512110550366,
#  413.36678250293045,
# ...

# %% [markdown]
# #### Use your code from practical session 1 and create a function to perform GD for single variable linear regression.
# #### The function should take the following input parameters:
# ##### Input data (X), Target Labels (y), Learning Rate (alpha), Maximum number of iterations
# #### The function should return the following:
# ##### All Theta_0 and Theta_1 values till converge, and equivellant Losses, all hypothesis output, and optimum values of Theta_0 and Theta_1
# #### Note: you can choose any suitable stop criteria.

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show();

# %% [markdown]
# #### Try your function with any input parameterss of your choice.

# %%
print(all_theta1)
# Out:
# [-0.2593877551020409, -0.48364756768013334, -0.6775370852987277, -0.8451695906007691, -0.9901012726212131, -1.1154066782731273, -1.2237439448568164, -1.3174111976268725, -1.3983953090015335, -1.4684140539360704, -1.5289525558686676, -1.5812947965106214, -1.6265508580225072, -1.6656804755722177, -1.6995133999883227, -1.7287670025421593, -1.754061495378436, -1.775933090525473, -1.7948453766791472, -1.8111991551411954, -1.8253409436004984, -1.8375703281816453, -1.8481463197488297, -1.8572928493264607, -1.865203519232556, -1.8720457107294783, -1.8779641353438348, -1.8830839052037198, -1.8875131875364934, -1.8913454996474413, -1.8946616930717666, -1.8975316689975665, -1.9000158613558387, -1.902166519044163, -1.9040288144889368, -1.9056418020664723, -1.9070392467177288, -1.9082503403373585, -1.9093003211366548, -1.9102110091213982, -1.911001269045805, -1.9116874106650508, -1.9122835347785059, -1.9128018324056653, -1.9132528434423735, -1.9136456802852417, -1.9139882211688837, -1.91428727731
# ...

# %% [markdown]
# #### Calculate r2 score

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y,hypothesis)
print(r2)
print('in percentage',r2*100,'%')
# Out:
# 0.9976352360258535
# in percentage 99.76352360258535 %

# %% [markdown]
# #### Plot loss vs. epochs

# %%
plt.plot(cost)
plt.xlabel('Itterations')
plt.ylabel('cost')
# Out:
# Text(0, 0.5, 'cost')

# %% [markdown]
# #### Plot Theta_0 vs. loss and Theta_1 vs. loss

# %%
plt.plot(all_theta0,cost)
plt.xlabel('theta_0')
plt.ylabel('cost')
plt.show()

# %%
plt.plot(all_theta1,cost)
plt.xlabel('theta_1')
plt.ylabel('cost')
plt.show()

# %% [markdown]
# #### Plot all regression lines till converge

# %%
for i in range(len(all_h)):
    plt.plot(x,all_h[i])
plt.show()

# %% [markdown]
# #### Plot the best regression line

# %%
plt.plot(x,hypothesis)
plt.title('Best regression line')
plt.show()

# %% [markdown]
# #### Update the implementation of the Batch GD to be Mini-Batch and repeat the above plots and evaluations
# #### Change batch size and see the effect
# ### Note: Try once without shuffling the data and once with shuffle and see the effect on the output.

# %%
def mini_batch(x,y,alpha,max_iter,batch_size):
    theta_0=0
    theta_1=0
    all_theta0=[]
    all_theta1=[]
    costs=[]
    x_batch=[]
    y_batch=[]
    all_y=[]
    y_p = []
    num=0
    mini_iter=max_iter//batch_size
    
    for j in range(max_iter):
        for i in range(mini_iter):
            size = i*batch_size
            hypothesis=theta_0+theta_1*x[size:size+batch_size]
            cost=(1/(2*batch_size))*((np.linalg.norm(hypothesis-y[size:size+batch_size]))**2)
            gradient=[(1/batch_size)*np.sum(hypothesis-y[size:size+batch_size]),(1/batch_size)*np.sum(x[size:size+batch_size].dot(hypothesis-y[size:size+batch_size]))]
            theta_0=theta_0-alpha*gradient[0]
            theta_1=theta_1-alpha*gradient[1]
            all_theta0.append(theta_0)
            all_theta1.append(theta_1)
            costs.append(cost)
    return all_theta0,all_theta1,costs
thetas_0,thetas_1,costs=mini_batch(x,y,0.0001,50,5)

# %%
y_pred=thetas_0[-1]+thetas_1[-1]*x
y_pred
from sklearn.metrics import r2_score
r2 = r2_score(y,y_pred)
print(r2)
print('in percentage',r2*100,'%')
# Out:
# 0.9976315744080584
# in percentage 99.76315744080584 %

# %%
plt.plot(costs)
plt.xlabel("epochs")
plt.ylabel("MSE Loss")
plt.show()

# %%
plt.plot(thetas_0 ,costs)
plt.xlabel("Theta_0")
plt.ylabel("MSE Loss")
plt.show()

# %%
plt.plot(thetas_1,costs)
plt.xlabel("Theta_1")
plt.ylabel("MSE Loss")
plt.show()

# %%
y_best= thetas_0[-1]+thetas_1[-1]*x
plt.scatter(x,y)
plt.plot(x, y_best,'r')

# %% [markdown]
# ## Stochastic GD

# %% [markdown]
# #### Update the implementation of the Batch GD to beStochastic and rpeat the above plots and evaluations
# #### You can try different learning rate and see its effect.
# #### Compare to Batch and Mini-Batch GD
# ### Note: Try once without shuffling the data and once with shuffle and see the effect on the output.

# %%
def stochastic(x, y,alpha,max_iter,batch_size):
    theta_0=0     
    theta_1=0
    costs=[]
    all_theta0=[]
    all_theta1=[]
    all_y=[]
    mini_iter=max_iter//batch_size
    for j in range(max_iter):
        for i in range(mini_iter):
            size = i*batch_size
            hypothesis=theta_0+theta_1*x[size:size+batch_size]
            cost=(1/(2*batch_size))*((np.linalg.norm(hypothesis-y[size:size+batch_size]))**2)
            gradient=[(1/batch_size)*np.sum(hypothesis-y[size:size+batch_size]),(1/batch_size)*np.sum(x[size:size+batch_size].dot(hypothesis-y[size:size+batch_size]))]
            theta_0=theta_0-alpha*gradient[0]
            theta_1=theta_1-alpha*gradient[1]
            all_theta0.append(theta_0)
            all_theta1.append(theta_1)
            costs.append(cost)
    return all_theta0,all_theta1,costs
thetas_0,thetas_1,costs = stochastic(x,y,0.00001,50,1)

# %%
y_pred=thetas_0[-1]+thetas_1[-1]*x
y_pred
# Out:
# array([ -0.13129775,  -0.88701893,  -1.64274011,  -2.39846129,
#         -3.15418247,  -3.90990365,  -4.66562483,  -5.421346  ,
#         -6.17706718,  -6.93278836,  -7.68850954,  -8.44423072,
#         -9.1999519 ,  -9.95567308, -10.71139426, -11.46711544,
#        -12.22283661, -12.97855779, -13.73427897, -14.49000015,
#        -15.24572133, -16.00144251, -16.75716369, -17.51288487,
#        -18.26860605, -19.02432722, -19.7800484 , -20.53576958,
#        -21.29149076, -22.04721194, -22.80293312, -23.5586543 ,
#        -24.31437548, -25.07009666, -25.82581783, -26.58153901,
#        -27.33726019, -28.09298137, -28.84870255, -29.60442373,
#        -30.36014491, -31.11586609, -31.87158727, -32.62730844,
#        -33.38302962, -34.1387508 , -34.89447198, -35.65019316,
#        -36.40591434, -37.16163552])

# %%
r2_score(y,y_pred)
# Out:
# 0.993587558119338

# %%
plt.plot(costs)
plt.xlabel("epochs")
plt.ylabel("MSE Loss")
plt.show()

# %%
plt.plot(thetas_0,costs)
plt.xlabel("Theta_0")
plt.ylabel("MSE Loss")
plt.show()

# %%
plt.plot(thetas_1,costs)
plt.xlabel("Theta_1")
plt.ylabel("MSE Loss")
plt.show()

# %%
y_best=thetas_0[-1]+thetas_1[-1]*x
plt.scatter(x,y)
plt.plot(x, y_best,'r')
